# %%
import numpy as np
import pandas as pd

# %%
link = 'https://en.wikipedia.org/wiki/List_of_American_films_of_2018'

# %%
df1 = pd.read_html(link,header=0)[2]
df2 = pd.read_html(link,header=0)[3]
df3 = pd.read_html(link,header=0)[4]
df4 = pd.read_html(link,header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  ...   Ref.
# 0     JANUARY  ...    [2]
# 1     JANUARY  ...    [3]
# 2     JANUARY  ...    [4]
# 3     JANUARY  ...    [5]
# 4     JANUARY  ...    [6]
# ..        ...  ...    ...
# 264  DECEMBER  ...  [163]
# 265  DECEMBER  ...  [137]
# 266  DECEMBER  ...  [226]
# 267  DECEMBER  ...  [258]
# 268  DECEMBER  ...  [259]
#
# [269 rows x 6 columns]

# %%
from tmdbv3api import TMDb
import json
import requests


tmdb = TMDb()
tmdb.api_key = '7767da907c5a44d336bd201316cdb8ab'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()

# %%
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#       Opening  ...                                           genres
# 0     JANUARY  ...                          Horror Mystery Thriller
# 1     JANUARY  ...                                   Thriller Drama
# 2     JANUARY  ...                                  Action Thriller
# 3     JANUARY  ...                            Drama History Western
# 4     JANUARY  ...                                  Action Thriller
# ..        ...  ...                                              ...
# 264  DECEMBER  ...                   Mystery Adventure Comedy Crime
# 265  DECEMBER  ...        Thriller Science Fiction Action Adventure
# 266  DECEMBER  ...                                    Drama History
# 267  DECEMBER  ...                      Thriller Crime Drama Action
# 268  DECEMBER  ...  Science Fiction Mystery Drama Thriller TV Movie
#
# [269 rows x 7 columns]

# %%
df_2018 = df[['Title','Cast and crew','genres']]
df_2018
# Out:
#                           Title  ...                                           genres
# 0       Insidious: The Last Key  ...                          Horror Mystery Thriller
# 1              The Strange Ones  ...                                   Thriller Drama
# 2                      Stratton  ...                                  Action Thriller
# 3                 Sweet Country  ...                            Drama History Western
# 4                  The Commuter  ...                                  Action Thriller
# ..                          ...  ...                                              ...
# 264             Holmes & Watson  ...                   Mystery Adventure Comedy Crime
# 265                        Vice  ...        Thriller Science Fiction Action Adventure
# 266         On the Basis of Sex  ...                                    Drama History
# 267                   Destroyer  ...                      Thriller Crime Drama Action
# 268  Black Mirror: Bandersnatch  ...  Science Fiction Mystery Drama Thriller TV Movie
#
# [269 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_2018
# Out:
#                           Title  ...    actor_3_name
# 0       Insidious: The Last Key  ...  Leigh Whannell
# 1              The Strange Ones  ...   Emily Althaus
# 2                      Stratton  ...      Gemma Chan
# 3                 Sweet Country  ...             NaN
# 4                  The Commuter  ...  Patrick Wilson
# ..                          ...  ...             ...
# 264             Holmes & Watson  ...    Rebecca Hall
# 265                        Vice  ...    Steve Carell
# 266         On the Basis of Sex  ...  Justin Theroux
# 267                   Destroyer  ...    Toby Kebbell
# 268  Black Mirror: Bandersnatch  ...   Asim Chaudhry
#
# [269 rows x 7 columns]

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})
new_df18 = df_2018.loc[:,['movie_title','genres','director_name','actor_1_name','actor_2_name','actor_3_name',]]

# %%
new_df18.isnull().sum()
# Out:
# movie_title       0
# genres            3
# director_name     0
# actor_1_name      0
# actor_2_name      9
# actor_3_name     26
# dtype: int64

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18.isnull().sum()
# Out:
# movie_title      0
# genres           3
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# dtype: int64

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#                     movie_title  ...                                               comb
# 0       insidious: the last key  ...  Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1              the strange ones  ...  Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2                      stratton  ...  Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3                 sweet country  ...  Bryan Brown Sam Neill unknown Warwick Thornton...
# 4                  the commuter  ...  Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                          ...  ...                                                ...
# 264             holmes & watson  ...  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 265                        vice  ...  Christian Bale Amy Adams Steve Carell Adam McK...
# 266         on the basis of sex  ...  Felicity Jones Armie Hammer Justin Theroux Mim...
# 267                   destroyer  ...  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 268  black mirror: bandersnatch  ...  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# [269 rows x 7 columns]

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  ...   Ref.
# 0     JANUARY  ...    [2]
# 1     JANUARY  ...    [3]
# 2     JANUARY  ...    [4]
# 3     JANUARY  ...    [5]
# 4     JANUARY  ...    [6]
# ..        ...  ...    ...
# 237  DECEMBER  ...  [132]
# 238  DECEMBER  ...  [221]
# 239  DECEMBER  ...  [222]
# 240  DECEMBER  ...  [223]
# 241  DECEMBER  ...  [224]
#
# [242 rows x 6 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df_2019 = df[['Title','Cast and crew','genres']]
df_2019
# Out:
#                  Title  ...                                    genres
# 0          Escape Room  ...  Thriller Action Mystery Adventure Horror
# 1           Rust Creek  ...                            Thriller Drama
# 2     American Hangman  ...                                  Thriller
# 3     A Dog's Way Home  ...                    Drama Adventure Family
# 4           The Upside  ...                              Comedy Drama
# ..                 ...  ...                                       ...
# 237  Spies in Disguise  ...  Animation Action Adventure Comedy Family
# 238       Little Women  ...                             Drama Romance
# 239               1917  ...                 War Drama Action Thriller
# 240         Just Mercy  ...                       Drama Crime History
# 241           Clemency  ...                                     Drama
#
# [242 rows x 3 columns]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_2019
# Out:
#                  Title  ...      actor_3_name
# 0          Escape Room  ...  Deborah Ann Woll
# 1           Rust Creek  ...      Sean O'Bryan
# 2     American Hangman  ...     Oliver Dennis
# 3     A Dog's Way Home  ...   Alexandra Shipp
# 4           The Upside  ...     Nicole Kidman
# ..                 ...  ...               ...
# 237  Spies in Disguise  ...     Rashida Jones
# 238       Little Women  ...     Florence Pugh
# 239               1917  ...       Mark Strong
# 240         Just Mercy  ...       Brie Larson
# 241           Clemency  ...       Aldis Hodge
#
# [242 rows x 7 columns]

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})
new_df19 = df_2019.loc[:,['movie_title','genres','director_name','actor_1_name','actor_2_name','actor_3_name',]]

# %%
new_df19.isnull().sum()
# Out:
# movie_title       0
# genres            0
# director_name     0
# actor_1_name      0
# actor_2_name      1
# actor_3_name     15
# dtype: int64

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#            movie_title  ...                                               comb
# 0          escape room  ...  Taylor Russell Logan Miller Deborah Ann Woll A...
# 1           rust creek  ...  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# 2     american hangman  ...  Donald Sutherland Vincent Kartheiser Oliver De...
# 3     a dog's way home  ...  Bryce Dallas Howard Edward James Olmos Alexand...
# 4           the upside  ...  Bryan Cranston Kevin Hart Nicole Kidman Neil B...
# ..                 ...  ...                                                ...
# 237  spies in disguise  ...  Will Smith Tom Holland Rashida Jones Nick Brun...
# 238       little women  ...  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 239               1917  ...  George MacKay Dean-Charles Chapman Mark Strong...
# 240         just mercy  ...  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 241           clemency  ...  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [242 rows x 7 columns]

# %%
my_df = new_df18.append(new_df19,ignore_index=True)
my_df
# Out:
#                  movie_title  ...                                               comb
# 0    insidious: the last key  ...  Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1           the strange ones  ...  Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2                   stratton  ...  Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3              sweet country  ...  Bryan Brown Sam Neill unknown Warwick Thornton...
# 4               the commuter  ...  Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                       ...  ...                                                ...
# 506        spies in disguise  ...  Will Smith Tom Holland Rashida Jones Nick Brun...
# 507             little women  ...  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 508                     1917  ...  George MacKay Dean-Charles Chapman Mark Strong...
# 509               just mercy  ...  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 510                 clemency  ...  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [511 rows x 7 columns]

# %%
old_df = pd.read_csv('new_data.csv')

# %%
old_df
# Out:
#                                             movie_title  ...                                               comb
# 0                                                avatar  ...  CCH Pounder Joel David Moore Wes Studi James C...
# 1              pirates of the caribbean: at world's end  ...  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2                                               spectre  ...  Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3                                 the dark knight rises  ...  Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     star wars: episode vii - the force awakens    ...  ...  Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...  ...                                                ...
# 5359                       the incredible jessica james  ...  Jessica Williams Chris O'Dowd Keith Stanfield ...
# 5360                                  can't buy my love  ...  Adelaide Kane Benjamin Hollingsworth Jean Loui...
# 5361                   thick lashes of lauri mäntyvaara  ...  Inka Haapamäki Rosa Honkonen Tiitus Rantala Ha...
# 5362                        cop and a half: new recruit  ...  Lou Diamond Phillips Wallace Shawn Gina Holden...
# 5363                                                mom  ...  Sridevi Kapoor Sajal Ali Akshaye Khanna Ravi U...
#
# [5364 rows x 7 columns]

# %%
final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df
# Out:
#                                             movie_title  ...                                               comb
# 0                                                avatar  ...  CCH Pounder Joel David Moore Wes Studi James C...
# 1              pirates of the caribbean: at world's end  ...  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2                                               spectre  ...  Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3                                 the dark knight rises  ...  Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     star wars: episode vii - the force awakens    ...  ...  Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...  ...                                                ...
# 5870                                  spies in disguise  ...  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5871                                       little women  ...  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5872                                               1917  ...  George MacKay Dean-Charles Chapman Mark Strong...
# 5873                                         just mercy  ...  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5874                                           clemency  ...  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5875 rows x 7 columns]

# %%
final_df.isnull().sum()
# Out:
# movie_title      0
# genres           3
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# comb             3
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

final_df.isna().sum()
# Out:
# movie_title      0
# genres           0
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# comb             0
# dtype: int64

# %%
final_df.to_csv('final_data.csv',index=False)
